# %%
import pandas as pd
import numpy as np
import os
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

import scipy
import numpy as np
from scipy import interpolate
from io import StringIO

# %% [markdown]
# # Reading data for 3 resolutions

# %% [markdown]
# CSV format

# %%
#from bigfloat import *

def isNaN(string):
    return string != string
print(isNaN("hello"))
print(isNaN(np.nan))
# Out:
# False
# True

# %% [markdown]
# Muninn format

# %%
res=1
vars=["m", "beta", "psi", "derpsi"]
time=[]
grid=[]
m=[]
beta=[]
psi=[]
derpsi=[]
k=1

for var in vars:
    dir = "/home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/{}.txt".format(var)
    

    print(dir)

    with open(dir) as f:
        for line in f:

            index = line.find("Time")
            if index==1:
                if k==1:
                    time.append(line[index+7:len(line)-1])
                auxgrid=[]
                auxdata=[]
                

            else:
                a=line.split()
                if a!=[]:
                    if k==1:
                        auxgrid.append(float(a[0]))
                    auxdata.append(float(a[1]))
                elif a==[]:
                    grid.append(auxgrid)
                    if k==1:
                        m.append(auxdata)
                    elif k==2:
                        beta.append(auxdata)
                    elif k==3:
                        psi.append(auxdata)
                    elif k==4:
                        derpsi.append(auxdata)
                    
    k=k+1

#count=len(datatime[2])+1
#count
# Out:
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/m.txt
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/beta.txt
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/psi.txt
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/derpsi.txt

# %%
time = [float(t) for t in time];

# %% [markdown]
# CSV format

# %%
"""step=10
run=20

#dir = "/home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/StoredDATA/28-05/bisectionsearchN7500/run{}".format(run)
dir = "/home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/res1"

    

count=0
for path in os.listdir(dir):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir, path)):
        count += 1
print('File count in dir', dir, 'is: ', count)


m=[]
beta=[]
psi=[]
derpsi=[]
grid=[]
    
#iterate over files in dir
for i in range(count-1):
    with pd.option_context('display.precision', 20):
        df = pd.read_csv(dir + "/time_step{}.csv".format(i*step), header=None, dtype = str)
    df = df.to_numpy()
    df = np.transpose(df)
        
    aux = [float(x) for x in df[0]]
    m.append(aux)
    aux = [float(x) for x in df[1]]
    beta.append(aux)
    aux = [float(x) for x in df[2]]
    psi.append(aux)
    aux = [float(x) for x in df[3]]
    derpsi.append(aux)
    aux = [float(x) for x in df[4]]
    grid.append(aux)

    # f[i] is the array of the values of m on the whole grid on time step i""";

# %% [markdown]
# ####

# %%
print(m[0][1]) # datam indexes give time then gridpoint
# Out:
# -5.149122319e-24

# %%
L=len(m[0])-6 # grid length without the ghostpoints
dx=grid[0][1]-grid[0][0]

# %%
t=0
plt_x1 = grid[t][3:len(grid[0])-3]

plt.plot(plt_x1,m[0][3:len(m[0])-3])

# %% [markdown]
# # Styling plots

# %%
plt.rcParams.update({'font.size': 12})

# %% [markdown]
# # Plotting data with resolutions 1 and 2 and differences

# %%
ustar=1.0284535606837135#time[len(time)-1] its this but with more precision

# %%
tau = [-math.log((ustar-x)/ustar) for x in time[0:len(time)-1]] #ignoring last timestep, where log(0)
monitor_ratio = []

L=len(m[0])

monitor_ratio=[]
for t in range(0,len(time)-1):
    aux=[]
    for x in range(4,L-3):
        aux.append(2*m[t][x]*(1-grid[t][x])/grid[t][x])
    monitor_ratio.append(max(aux))

# %%
phi=[]
for i in range(0, len(tau)):
    phi.append(psi[i][4]/grid[i][4])
    
    
with plt.style.context('fivethirtyeight'):
    
    plt.rcParams.update({'font.size': 12})    
    plt.rcParams["figure.figsize"] = (7,5)  
    plt.xlabel("$\u03C4$")
    plt.ylabel("$\phi$")
    #plt.ylim([-1,1])
    plt.scatter(tau,phi)

# %%
with plt.style.context('fivethirtyeight'):
    
    plt.rcParams.update({'font.size': 12})    
    plt.rcParams["figure.figsize"] = (7,5)  
    plt.xlabel("$\u03C4$")
    plt.ylabel("max 2m/r")
    plt.ylim([0,1])
    plt.scatter(tau,monitor_ratio)
    plt.axvline(x = 3.05, color = 'black', linestyle = 'solid', alpha=0.9,linewidth=1)
    plt.axvline(x = 4.95, color = 'black', linestyle = 'solid', alpha=0.9,linewidth=1)

# %%
4.95-3.05
# Out:
# 1.9000000000000004

# %%
plt.scatter(tau[600:1400],monitor_ratio[600:1400])


auxx=np.linspace(2,6,100)
y=f(auxx,0.17,2.9,0.4,3.4)
plt.plot(auxx,y)

# %%
#import numpy as np

#import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

def func(x,a,delta,c,d):
    #[a, delta, c, d]=pars
    return a * math.sin(d*x + delta) + c

# %%
f=np.vectorize(func)


# fit
guess = [0.17,2.9,0.4,3.4]

pars, cov = curve_fit(f, tau[600:1400],monitor_ratio[600:1400], p0=guess, maxfev=5000)

pars

plt.plot(tau[600:1400], f(tau[600:1400],pars[0],pars[1],pars[2],pars[3]))
plt.scatter(tau[600:1400],monitor_ratio[600:1400])
plt.show()

# %% [markdown]
# psi(tau)

# %%
x = grid[0][3:len(grid[0])-3]
y = tau

X, Y = np.meshgrid(x, y)

Z = []

for i in range(0,len(y)):
    Z.append(psi[i][3:len(grid[0])-3])

with plt.style.context('fivethirtyeight'):
    
    plt.rcParams.update({'font.size': 12})    
    plt.rcParams["figure.figsize"] = (10,10)  

    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.contour3D(X, Y, Z, 100, cmap='binary')
    ax.set_xlabel('x')
    ax.set_ylabel('tau')
    ax.set_zlabel('psi');
