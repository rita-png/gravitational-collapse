# %%
import pandas as pd
import numpy as np
import os
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

import scipy
import numpy as np
from scipy import interpolate
from io import StringIO

# %% [markdown]
# # Reading data

# %% [markdown]
# CSV format

# %%
#from bigfloat import *

def isNaN(string):
    return string != string
print(isNaN("hello"))
print(isNaN(np.nan))
# Out:
# False
# True

# %% [markdown]
# Muninn format

# %%
res=1
vars=["m", "beta", "psi", "derpsi"]
time=[]
grid=[]
m=[]
beta=[]
psi=[]
derpsi=[]
k=1

for var in vars:
    dir = "/home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/{}.txt".format(var)
    

    print(dir)

    with open(dir) as f:
        for line in f:

            index = line.find("Time")
            if index==1:
                if k==1:
                    time.append(line[index+7:len(line)-1])
                auxgrid=[]
                auxdata=[]
                

            else:
                a=line.split()
                if a!=[]:
                    if k==1:
                        auxgrid.append(float(a[0]))
                    auxdata.append(float(a[1]))
                elif a==[]:
                    grid.append(auxgrid)
                    if k==1:
                        m.append(auxdata)
                    elif k==2:
                        beta.append(auxdata)
                    elif k==3:
                        psi.append(auxdata)
                    elif k==4:
                        derpsi.append(auxdata)
                    
    k=k+1

#count=len(datatime[2])+1
#count
# Out:
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/m.txt
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/beta.txt
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/psi.txt
# /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/muninnDATA/res1/derpsi.txt

# %%
dir = "/home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/timearray1.csv"
time=[]

with open(dir) as f:
    with pd.option_context('display.precision', 20):
        df = pd.read_csv(dir, header=None, dtype = str)
        
        df = df.to_numpy()
        df = np.transpose(df)

time = [float(t) for t in df[0]]
print(time)
# Out:
# [0.0, 0.0002501250468906299, 0.0005002500937812598, 0.0007503751406718897, 0.0010005001875625196, 0.0012506252344531496, 0.0015007502813437796, 0.0017508753282344095, 0.0020010003751250393, 0.002251125422015669, 0.0025012504689062988, 0.0027513755157969285, 0.0030015005626875583, 0.003251625609578188, 0.0035017506564688178, 0.0037518757033594475, 0.004002000750250078, 0.0042521257971407074, 0.004502250844031337, 0.004752375890921967, 0.005002500937812597, 0.005252625984703226, 0.005502751031593856, 0.005752876078484486, 0.006003001125375116, 0.006253126172265745, 0.006503251219156375, 0.006753376266047005, 0.007003501312937635, 0.007253626359828264, 0.007503751406718894, 0.007753876453609524, 0.008004001500500154, 0.008254126547390784, 0.008504251594281415, 0.008754376641172045, 0.009004501688062676, 0.009254626734953307, 0.009504751781843937, 0.009754876828734568, 0.010005001875625199, 0.01025512692251583, 0.01050525196940646, 0.01075537701629709, 0.011005502063187721, 0.011255627110078352, 0.011505752156968982, 0.011755877203859613, 0.012006002250750243, 0.012256127297640874, 0.012506252344531505, 0.012756377391422135, 0.013006502438312766, 0.013256627485203397, 0.013506752532094027, 0.013756877578984658, 0.014007002625875288, 0.014257127672765919, 0.01450725271965655, 0.01475737776654718, 0.01500750281343781, 0.015257627860328441, 0.015507752907219072, 0.0157578779541097, 0.01600800300100033, 0.016258128047890962, 0.016508253094781593, 0.016758378141672223, 0.017008503188562854, 0.017258628235453485, 0.017508753282344115, 0.017758878329234746, 0.018009003376125376, 0.018259128423016007, 0.018509253469906638, 0.01875937851679727, 0.0190095035636879, 0.01925962861057853, 0.01950975365746916, 0.01975987870435979, 0.02001000375125042, 0.020260128798141052, 0.020510253845031683, 0.020760378891922313, 0.021010503938812944, 0.021260628985703574, 0.021510754032594205, 0.021760879079484836, 0.022011004126375466, 0.022261129173266097, 0.022511254220156728, 0.022761379267047358, 0.02301150431393799, 0.02326162936082862, 0.02351175440771925, 0.02376187945460988, 0.02401200450150051, 0.024262129548391142, 0.024512254595281772, 0.024762379642172403, 0.025012504689063034, 0.025262629735953664, 0.025512754782844295, 0.025762879829734926, 0.026013004876625556, 0.026263129923516187, 0.026513254970406817, 0.026763380017297448, 0.02701350506418808, 0.02726363011107871, 0.02751375515796934, 0.02776388020485997, 0.0280140052517506, 0.02826413029864123, 0.028514255345531862, 0.028764380392422493, 0.029014505439313124, 0.029264630486203754, 0.029514755533094385, 0.029764880579985015, 0.030015005626875646, 0.030265130673766277, 0.030515255720656907, 0.030765380767547538, 0.03101550581443817, 0.031265630861328796, 0.03151575590821942, 0.03176588095511005, 0.03201600600200068, 0.032266131048891304, 0.03251625609578193, 0.03276638114267256, 0.033016506189563186, 0.03326663123645381, 0.03351675628334444, 0.03376688133023507, 0.034017006377125694, 0.03426713142401632, 0.03451725647090695, 0.034767381517797576, 0.0350175065646882, 0.03526763161157883, 0.03551775665846946, 0.035767881705360084, 0.03601800675225071, 0.03626813179914134, 0.036518256846031966, 0.03676838189292259, 0.03701850693981322, 0.03726863198670385, 0.037518757033594474, 0.0377688820804851, 0.03801900712737573, 0.038269132174266356, 0.03851925722115698, 0.03876938226804761, 0.03901950731493824, 0.039269632361828864, 0.03951975740871949, 0.03976988245561012, 0.040020007502500746, 0.04027013254939137, 0.040520257596282, 0.04077038264317263, 0.041020507690063254, 0.04127063273695388, 0.04152075778384451, 0.041770882830735136, 0.04202100787762576, 0.04227113292451639, 0.04252125797140702, 0.042771383018297644, 0.04302150806518827, 0.0432716331120789, 0.043521758158969526, 0.04377188320586015, 0.04402200825275078, 0.04427213329964141, 0.044522258346532034, 0.04477238339342266, 0.04502250844031329, 0.045272633487203916, 0.04552275853409454, 0.04577288358098517, 0.0460230086278758, 0.04627313 ...

# %% [markdown]
# CSV format

# %%
step=1
run=20

#dir = "/home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/StoredDATA/28-05/bisectionsearchN7500/run{}".format(run)
dir = "/home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/res1"

    

count=0
for path in os.listdir(dir):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir, path)):
        count += 1
print('File count in dir', dir, 'is: ', count)


m=[]
beta=[]
psi=[]
derpsi=[]
grid=[]
    
#iterate over files in dir
for i in range(count-1):
    with pd.option_context('display.precision', 20):
        df = pd.read_csv(dir + "/time_step{}.csv".format(i*step), header=None, dtype = str)
    df = df.to_numpy()
    df = np.transpose(df)
        
    aux = [float(x) for x in df[0]]
    m.append(aux)
    aux = [float(x) for x in df[1]]
    beta.append(aux)
    aux = [float(x) for x in df[2]]
    psi.append(aux)
    aux = [float(x) for x in df[3]]
    derpsi.append(aux)
    aux = [float(x) for x in df[4]]
    grid.append(aux)

    # f[i] is the array of the values of m on the whole grid on time step i""";
# Out:
# File count in dir /home/rita13santos/Desktop/MSc Thesis/Git/ScalarField/DATA/res1 is:  4857

# %% [markdown]
# ####

# %%
print(m[0][1]) # datam indexes give time then gridpoint
# Out:
# -1.2296997932129055e-22

# %%
L=len(m[0])-6 # grid length without the ghostpoints
dx=grid[0][1]-grid[0][0]

# %%
t=0
plt_x1 = grid[t][3:len(grid[0])-3]

plt.plot(plt_x1,m[0][3:len(m[0])-3])

# %% [markdown]
# # Styling plots

# %%
plt.rcParams.update({'font.size': 12})

# %% [markdown]
# # Plotting data with resolutions 1 and 2 and differences

# %%
ustar=time[len(time)-1]
print(ustar)
# Out:
# 1.0087035724169493

# %%
tau = [-math.log((ustar-x)/ustar) for x in time[0:len(time)-1]] #ignoring last timestep, where log(0)
monitor_ratio = []

L=len(m[0])

monitor_ratio=[]
for t in range(0,len(time)-1):
    aux=[]
    for x in range(4,L-3):
        aux.append(2*m[t][x]*(1-grid[t][x])/grid[t][x])
    monitor_ratio.append(max(aux))

# %%
phi=[]
for i in range(0, len(tau)):
    phi.append(psi[i][4]/grid[i][4])
    
    
with plt.style.context('fivethirtyeight'):
    
    plt.rcParams.update({'font.size': 12})    
    plt.rcParams["figure.figsize"] = (7,5)  
    plt.xlabel("$\u03C4$")
    plt.ylabel("$\phi$")
    #plt.ylim([-1,1])
    plt.scatter(tau,phi)

# %%
with plt.style.context('fivethirtyeight'):
    
    plt.rcParams.update({'font.size': 12})    
    plt.rcParams["figure.figsize"] = (7,5)  
    plt.xlabel("$\u03C4$")
    plt.ylabel("max 2m/r")
    plt.ylim([0,1])
    plt.scatter(tau,monitor_ratio)
    #plt.axvline(x = 3.05, color = 'black', linestyle = 'solid', alpha=0.9,linewidth=1)
    #plt.axvline(x = 4.95, color = 'black', linestyle = 'solid', alpha=0.9,linewidth=1)

# %%
4.95-3.05
# Out:
# 1.9000000000000004

# %%
plt.scatter(tau[600:1400],monitor_ratio[600:1400])


auxx=np.linspace(2,6,100)
y=f(auxx,0.17,2.9,0.4,3.4)
plt.plot(auxx,y)

# %%
#import numpy as np

#import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

def func(x,a,delta,c,d):
    #[a, delta, c, d]=pars
    return a * math.sin(d*x + delta) + c

# %%
f=np.vectorize(func)


# fit
guess = [0.17,2.9,0.4,3.4]

pars, cov = curve_fit(f, tau[600:1400],monitor_ratio[600:1400], p0=guess, maxfev=5000)

pars

plt.plot(tau[600:1400], f(tau[600:1400],pars[0],pars[1],pars[2],pars[3]))
plt.scatter(tau[600:1400],monitor_ratio[600:1400])
plt.show()

# %% [markdown]
# psi(tau)

# %%
x = grid[0][3:len(grid[0])-3]
y = tau

X, Y = np.meshgrid(x, y)

Z = []

for i in range(0,len(y)):
    Z.append(psi[i][3:len(grid[0])-3])

with plt.style.context('fivethirtyeight'):
    
    plt.rcParams.update({'font.size': 12})    
    plt.rcParams["figure.figsize"] = (10,10)  

    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.contour3D(X, Y, Z, 100, cmap='binary')
    ax.set_xlabel('x')
    ax.set_ylabel('tau')
    ax.set_zlabel('psi');
